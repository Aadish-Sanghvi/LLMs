# %% [markdown]
# # 0. Install and Import Dependencies

# %%
from transformers import pipeline 
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# # 1. Load Model

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")
model = GPT2LMHeadModel.from_pretrained("gpt2-large", pad_token_id=tokenizer.eos_token_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %% [markdown]
# # 2. Tokenize Sentences

# %%
sentence = 'As a Virat Kohli fan, '
input_ids = tokenizer.encode(sentence, return_tensors='pt')
input_ids
# Out:
# tensor([[ 1722,   257, 16310,   265, 24754,  4528,  4336,    11,   220]])

# %% [markdown]
# # 3. Generate and Decode Text

# %%
# generate text until the output length (which includes the context length) reaches 50
output = model.generate(input_ids, max_length=50, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)

# %%
output
# Out:
# tensor([[ 1722,   257, 16310,   265, 24754,  4528,  4336,    11,   220,  1849,
#             40,   460,   470,  4043,   284,   766,   644,   339,   857,   287,
#            262,  1306,  3155,   286,   812,    13,   679,   468,   262,  2785,
#            284,   307,   530,   286,   262,  1266, 19553,  3653,   284,  1683,
#            711,   262,   983,    13, 50256]])

# %%
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# As a Virat Kohli fan,  I can't wait to see what he does in the next couple of years. He has the potential to be one of the best batsmen to ever play the game.
